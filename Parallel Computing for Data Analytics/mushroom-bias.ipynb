# %%
# imports and installs

import sys, os
old_stdout = sys.stdout
sys.stdout = open(os.devnull, "w")
# !{sys.executable} -m pip install -q awswrangler pandas;
# !{sys.executable} -m pip install -qU awscli boto3 "sagemaker==2.84.0";
sys.stdout = old_stdout

# %%
# imports and installs

from sagemaker import Session

session = Session()
bucket = session.default_bucket()
prefix = "sagemaker/DEMO-sagemaker-clarify"
region = session.boto_region_name
# Define IAM role
from sagemaker import get_execution_role
import pandas as pd
import numpy as np
import os
import boto3

role = get_execution_role()
s3_client = boto3.client("s3")

# %%
# put data into dataframe

import pandas as pd

df = pd.read_csv("agaricus-lepiota.data")
df.head()
# Out:
#    p  x  s  n  t p.1  f  c n.1  k  ... s.2  w w.1 p.2 w.2  o p.3 k.1 s.3  u
# 0  e  x  s  y  t   a  f  c   b  k  ...   s  w   w   p   w  o   p   n   n  g
# 1  e  b  s  w  t   l  f  c   b  n  ...   s  w   w   p   w  o   p   n   n  m
# 2  p  x  y  w  t   p  f  c   n  n  ...   s  w   w   p   w  o   p   k   s  u
# 3  e  x  s  g  f   n  f  w   b  k  ...   s  w   w   p   w  o   e   n   a  g
# 4  e  x  y  y  t   a  f  c   b  n  ...   s  w   w   p   w  o   p   k   n  g
#
# [5 rows x 23 columns]

# %%
# separate into testing and training

from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.3, train_size=0.7)

# %%
# preprocessing

from sklearn import preprocessing


def number_encode_features(df):
    result = df.copy()
    encoders = {}
    for column in result.columns:
        if result.dtypes[column] == np.object:
            encoders[column] = preprocessing.LabelEncoder()
            result[column] = encoders[column].fit_transform(result[column].fillna("None"))
    return result, encoders


train = pd.concat([train["p"], train.drop(["p"], axis=1)], axis=1)
train, _ = number_encode_features(train)
train.to_csv("train_data.csv", index=False, header=False)

test, _ = number_encode_features(test)
test_features = test.drop(["p"], axis=1)
test_target = test["p"]
test_features.to_csv("test_features.csv", index=False, header=False)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   # Remove the CWD from sys.path while we load stuff.

# %%
from sagemaker.s3 import S3Uploader
from sagemaker.inputs import TrainingInput

train_uri = S3Uploader.upload("train_data.csv", "s3://{}/{}".format(bucket, prefix))
train_input = TrainingInput(train_uri, content_type="csv")
test_uri = S3Uploader.upload("test_features.csv", "s3://{}/{}".format(bucket, prefix))

# %%
# training

from sagemaker.image_uris import retrieve
from sagemaker.estimator import Estimator

container = retrieve("xgboost", region, version="1.2-1")
xgb = Estimator(
    container,
    role,
    instance_count=1,
    instance_type="ml.m5.xlarge",
    disable_profiler=True,
    sagemaker_session=session,
)

xgb.set_hyperparameters(
    max_depth=5,
    eta=0.2,
    gamma=4,
    min_child_weight=6,
    subsample=0.8,
    objective="binary:logistic",
    num_round=800,
)

xgb.fit({"train": train_input}, logs=False)
# Out:
# 2022-04-20 16:55:07 Starting - Starting the training job.....
# 2022-04-20 16:55:37 Starting - Preparing the instances for training..............
# 2022-04-20 16:56:52 Downloading - Downloading input data....
# 2022-04-20 16:57:18 Training - Downloading the training image..........
# 2022-04-20 16:58:13 Training - Training image download completed. Training in progress....
# 2022-04-20 16:58:29 Uploading - Uploading generated training model
# 2022-04-20 16:58:35 Completed - Training job completed

# %%
model_name = "DEMO-clarify-model"
model = xgb.create_model(name=model_name)
container_def = model.prepare_container_def()
session.create_model(model_name, role, container_def)
# Out:
# Using already existing model: DEMO-clarify-model
# 'DEMO-clarify-model'

# %%
from sagemaker import clarify

clarify_processor = clarify.SageMakerClarifyProcessor(
    role=role, instance_count=1, instance_type="ml.m5.xlarge", sagemaker_session=session
)

# %%
# get bias report

bias_report_output_path = "s3://{}/{}/clarify-bias".format(bucket, prefix)
bias_data_config = clarify.DataConfig(
    s3_data_input_path=train_uri,
    s3_output_path=bias_report_output_path,
    label="p",
    headers=train.columns.to_list(),
    dataset_type="text/csv",
)
# Out:
# DataConfig will be deprecated on 15 Mar 2022.s3_data_distribution_type parameter will no longer be supported. Everything else will remain as is in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
model_config = clarify.ModelConfig(
    model_name=model_name,
    instance_type="ml.m5.xlarge",
    instance_count=1,
    accept_type="text/csv",
    content_type="text/csv",
)

# %%
predictions_config = clarify.ModelPredictedLabelConfig(probability_threshold=0.8)

# %%
bias_config = clarify.BiasConfig(
    label_values_or_threshold=[1], facet_name="x", facet_values_or_threshold=[0], group_name="s"
)

# %%
clarify_processor.run_bias(
    data_config=bias_data_config,
    bias_config=bias_config,
    model_config=model_config,
    model_predicted_label_config=predictions_config,
    pre_training_methods="all",
    post_training_methods="all",
)
# Out:
# Job Name:  Clarify-Bias-2022-04-20-17-12-02-472
# Inputs:  [{'InputName': 'dataset', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-us-east-1-714861692883/sagemaker/DEMO-sagemaker-clarify/train_data.csv', 'LocalPath': '/opt/ml/processing/input/data', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}, {'InputName': 'analysis_config', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-us-east-1-714861692883/sagemaker/DEMO-sagemaker-clarify/clarify-bias/analysis_config.json', 'LocalPath': '/opt/ml/processing/input/config', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}]
# Outputs:  [{'OutputName': 'analysis_result', 'AppManaged': False, 'S3Output': {'S3Uri': 's3://sagemaker-us-east-1-714861692883/sagemaker/DEMO-sagemaker-clarify/clarify-bias', 'LocalPath': '/opt/ml/processing/output', 'S3UploadMode': 'EndOfJob'}}]
# ...............................2022-04-20 17:17:02,208 logging.conf not found when configuring logging, using default logging configuration.
# 2022-04-20 17:17:02,209 Starting SageMaker Clarify Processing job
# 2022-04-20 17:17:02,209 Analysis config path: /opt/ml/processing/input/config/analysis_config.json
# 2022-04-20 17:17:02,209 Analysis result path: /opt/ml/processing/output
# 2022-04-20 17:17:02,210 This host is algo-1.
# 2022-04-20 17:17:02,210 This host is the leader.
# 2022-04-20 17:17:02,210 Number of hosts in the cluster is 1.
# 2022-04-20 17:17:02,381 Running Python / Pandas based analyzer.
# 2022-04-20 17:17:02,381 Dataset type: text/csv uri: /opt/ml/processing/input/data
# 2022-04-20 17:17:02,393 Loading dataset...
# 2022-04-20 17:17:02,412 Loaded dataset. Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5686 entries, 0 to 5685
# Data columns (total 22 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       5686 non-null   int64
#  1   s       5686 non-null   int64
#  2   n       5686 non-null   int64
#  3   t       5686 non-null   int64
#  4   p.1     5686 non-null   int64
#  5   f       5686 non-null   int64
#  6   c       5686 non-null   int64
#  7   n.1     5686 non-null   int64
#  8   k       5686 non-null   int64
#  9   e       5686 non-null   int64
#  10  e.1     5686 non-null   int64
#  11  s.1     5686 non-null   int64
#  12  s.2     5686 non-null   int64
#  13  w       5686 non-null   int64
#  14  w.1     5686 non-null   int64
#  15  p.2     5686 non-null   int64
#  16  w.2     5686 non-null   int64
#  17  o       5686 non-null   int64
#  18  p.3     5686 non-null   int64
#  19  k.1     5686 non-null   int64
#  20  s.3     5686 non-null   int64
#  21  u       5686 non-null   int64
# dtypes: int64(22)
# memory usage: 977.4 KB
# 2022-04-20 17:17:02,558 Spinning up shadow endpoint
# 2022-04-20 17:17:02,558 Creating endpoint-config with name sm-clarify-config-1650475022-95c3
# 2022-04-20 17:17:02,667 Creating endpoint: 'sm-clarify-DEMO-clarify-model-1650475022-7250'
# 2022-04-20 17:17:02,945 Using endpoint name: sm-clarify-DEMO-clarify-model-1650475022-7250
# 2022-04-20 17:17:02,945 Waiting for endpoint ...
# 2022-04-20 17:17:02,945 Checking endpoint status:
# Legend:
# (OutOfService: x, Creating: -, Updating: -, InService: !, RollingBack: <, Deleting: o, Failed: *)
#
# 2022-04-20 17:20:03,427 Endpoint is in service after 180 seconds
# 2022-04-20 17:20:03,427 Endpoint ready.
# 2022-04-20 17:20:03,427 ======================================
# 2022-04-20 17:20:03,427 Calculating post-training bias metrics
# 2022-04-20 17:20:03,427 ======================================
# 2022-04-20 17:20:03,427 Getting predictions from the endpoint
# 2022-04-20 17:20:04,040 We assume a prediction above 0.800 indicates 1 and below or equal indicates 0.
# 2022-04-20 17:20:04,041 Column p with data uniqueness fraction 0.00035174111853675694 is classifed as a CATEGORICAL column
# 2022-04-20 17:20:04,043 Column x with data uniqueness fraction 0.001055223355610271 is classifed as a CATEGORICAL column
# 2022-04-20 17:20:04,045 Column p with data uniqueness fraction 0.00035174111853675694 is classifed as a CATEGORICAL column
# 2022-04-20 17:20:04,047 Column None with data uniqueness fraction 0.00035174111853675694 is classifed as a CATEGORICAL column
# 2022-04-20 17:20:04,256 Stop using endpoint: sm-clarify-DEMO-clarify-model-1650475022-7250
# 2022-04-20 17:20:04,256 Deleting endpoint configuration with name: sm-clarify-config-1650475022-95c3
# 2022-04-20 17:20:04,424 Deleting endpoint with name: sm-clarify-DEMO-clarify-model-1650475022-7250
# 2022-04-20 17:20:04,565 Model endpoint delivered 2.41228 requests per second and a total of 2 requests over 1 seconds
# 2022-04-20 17:20:04,565 Stop using endpoint: None
# 2022-04-20 17:20:04,565 =====================================
# 2022-04-20 17:20:04,565 Calculating pre-training bias metrics
# 2022-04-20 17:20:04,565 =====================================
# 2022-04-20 17:20:04,566 Column p with data uniqueness fraction 0.00035174111853675694 is classifed as a CATEGORICAL column
# 2022-04-20 17:20:04,568 Column x with data uniqueness fraction 0.001055223355610271 is classifed as a CATEGORICAL column
# 2022-04-20 17:20:04,570 Column p with data uniqueness fraction 0.00035174111853675694 is classifed as a CATEGORICAL column
# 2022-04-20 17:20:04,610 ======================================
# 2022-04-20 17:20:04,610 Calculating bias statistics for report
# 2022-04-20 17:20:04,611 ======================================
# 2022-04-20 17:20:04,611 Column p with data uniqueness fraction 0.00035174111853675694 is classifed as a CATEGORICAL column
# 2022-04-20 17:20:04,613 Column x with data uniqueness fraction 0.001055223355610271 is classifed as a CATEGORICAL column
# 2022-04-20 17:20:04,615 Column p with data uniqueness fraction 0.00035174111853675694 is classifed as a CATEGORICAL column
# 2022-04-20 17:20:04,617 Column None with data uniqueness fraction 0.00035174111853675694 is classifed as a CATEGORICAL column
# 2022-04-20 17:20:04,621 Stop using endpoint: None
# 2022-04-20 17:20:04,903 jupyter nbconvert --to html --output /opt/ml/processing/output/report.html /opt/ml/processing/output/report.ipynb --template sagemaker-xai
# [NbConvertApp] Converting notebook /opt/ml/processing/output/report.ipynb to html
# [NbConvertApp] Writing 341748 bytes to /opt/ml/processing/output/report.html
# 2022-04-20 17:20:05,885 HTML report '/opt/ml/processing/output/report.html' generated successfully.
# 2022-04-20 17:20:05,885 wkhtmltopdf -q /opt/ml/processing/output/report.html /opt/ml/processing/output/report.pdf
# 2022-04-20 17:20:06,380 PDF report '/opt/ml/processing/output/report.pdf' generated successfully.
# 2022-04-20 17:20:06,381 Collected analyses:
# {
#     "version": "1.0",
#     "post_training_bias_metrics": {
#         "label": "p",
#         "facets": {
#             "x": [
#                 {
#                     "value_or_threshold": "0",
#                     "metrics": [
#                         {
#                             "name": "AD",
#                             "description": "Accuracy Difference (AD)",
#                             "value": 0.004859725805545945
#                         },
#                         {
#                             "name": "CDDPL",
#                             "description": "Conditional Demographic Disparity in Predicted Labels (CDDPL)",
#                             "value": 0.09437905591661691
#                         },
#                         {
#                             "name": "DAR",
#                             "description": "Difference in Acceptance Rates (DAR)",
#                             "value": 0.0
#                         },
#                         {
#                             "name": "DCA",
#                             "description": "Difference in Conditional Acceptance (DCA)",
#                             "value": -0.059542513863216184
#                         },
#                         {
#                             "name": "DCR",
#                             "description": "Difference in Conditional Rejection (DCR)",
#                             "value": -0.004066387621640466
#                         },
#                         {
#                             "name": "DI",
#                             "description": "Disparate Impact (DI)",
#                             "value": 0.20170994337352935
#                         },
#                         {
#                             "name": "DPPL",
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "value": 0.40204330723787063
#                         },
#                         {
#                             "name": "DRR",
#                             "description": "Difference in Rejection Rates (DRR)",
#                             "value": -0.004066387621640466
#                         },
#                         {
#                             "name": "FT",
#                             "description": "Flip Test (FT)",
#                             "value": 0.009523809523809525
#                         },
#                         {
#                             "name": "RD",
#                             "description": "Recall Difference (RD)",
#                             "value": 0.05587476420719417
#                         },
#                         {
#                             "name": "TE",
#                             "description": "Treatment Equality (TE)",
#                             "value": 0.0
#                         }
#                     ]
#                 }
#             ]
#         },
#         "label_value_or_threshold": "1"
#     },
#     "pre_training_bias_metrics": {
#         "label": "p",
#         "facets": {
#             "x": [
#                 {
#                     "value_or_threshold": "0",
#                     "metrics": [
#                         {
#                             "name": "CDDL",
#                             "description": "Conditional Demographic Disparity in Labels (CDDL)",
#                             "value": 0.09323758569494658
#                         },
#                         {
#                             "name": "CI",
#                             "description": "Class Imbalance (CI)",
#                             "value": 0.8892015476609215
#                         },
#                         {
#                             "name": "DPL",
#                             "description": "Difference in Positive Proportions in Labels (DPL)",
#                             "value": 0.39718358143232463
#                         },
#                         {
#                             "name": "JS",
#                             "description": "Jensen-Shannon Divergence (JS)",
#                             "value": 0.09865766146886831
#                         },
#                         {
#                             "name": "KL",
#                             "description": "Kullback-Liebler Divergence (KL)",
#                             "value": 0.4879338916047911
#                         },
#                         {
#                             "name": "KS",
#                             "description": "Kolmogorov-Smirnov Distance (KS)",
#                             "value": 0.39718358143232474
#                         },
#                         {
#                             "name": "LP",
#                             "description": "L-p Norm (LP)",
#                             "value": 0.5617024076135122
#                         },
#                         {
#                             "name": "TVD",
#                             "description": "Total Variation Distance (TVD)",
#                             "value": 0.3971835814323247
#                         }
#                     ]
#                 }
#             ]
#         },
#         "label_value_or_threshold": "1"
#     }
# }
# 2022-04-20 17:20:06,381 exit_message: Completed: SageMaker XAI Analyzer ran successfully
# ---!

# %%
bias_report_output_path
# Out:
# 's3://sagemaker-us-east-1-714861692883/sagemaker/DEMO-sagemaker-clarify/clarify-bias'

# %%
shap_config = clarify.SHAPConfig(
    baseline=[test_features.iloc[0].values.tolist()],
    num_samples=15,
    agg_method="mean_abs",
    save_local_shap_values=True,
)

explainability_output_path = "s3://{}/{}/clarify-explainability".format(bucket, prefix)
explainability_data_config = clarify.DataConfig(
    s3_data_input_path=train_uri,
    s3_output_path=explainability_output_path,
    label="p",
    headers=train.columns.to_list(),
    dataset_type="text/csv",
)
# Out:
# DataConfig will be deprecated on 15 Mar 2022.s3_data_distribution_type parameter will no longer be supported. Everything else will remain as is in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
clarify_processor.run_explainability(
    data_config=explainability_data_config,
    model_config=model_config,
    explainability_config=shap_config,
)
# Out:
# Job Name:  Clarify-Explainability-2022-04-20-18-59-46-883
# Inputs:  [{'InputName': 'dataset', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-us-east-1-714861692883/sagemaker/DEMO-sagemaker-clarify/train_data.csv', 'LocalPath': '/opt/ml/processing/input/data', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}, {'InputName': 'analysis_config', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-us-east-1-714861692883/sagemaker/DEMO-sagemaker-clarify/clarify-explainability/analysis_config.json', 'LocalPath': '/opt/ml/processing/input/config', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}]
# Outputs:  [{'OutputName': 'analysis_result', 'AppManaged': False, 'S3Output': {'S3Uri': 's3://sagemaker-us-east-1-714861692883/sagemaker/DEMO-sagemaker-clarify/clarify-explainability', 'LocalPath': '/opt/ml/processing/output', 'S3UploadMode': 'EndOfJob'}}]
# ................................2022-04-20 19:04:55,824 logging.conf not found when configuring logging, using default logging configuration.
# 2022-04-20 19:04:55,824 Starting SageMaker Clarify Processing job
# 2022-04-20 19:04:55,825 Analysis config path: /opt/ml/processing/input/config/analysis_config.json
# 2022-04-20 19:04:55,825 Analysis result path: /opt/ml/processing/output
# 2022-04-20 19:04:55,825 This host is algo-1.
# 2022-04-20 19:04:55,825 This host is the leader.
# 2022-04-20 19:04:55,825 Number of hosts in the cluster is 1.
# 2022-04-20 19:04:55,999 Running Python / Pandas based analyzer.
# 2022-04-20 19:04:56,000 Dataset type: text/csv uri: /opt/ml/processing/input/data
# 2022-04-20 19:04:56,012 Loading dataset...
# 2022-04-20 19:04:56,030 Loaded dataset. Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5686 entries, 0 to 5685
# Data columns (total 22 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       5686 non-null   int64
#  1   s       5686 non-null   int64
#  2   n       5686 non-null   int64
#  3   t       5686 non-null   int64
#  4   p.1     5686 non-null   int64
#  5   f       5686 non-null   int64
#  6   c       5686 non-null   int64
#  7   n.1     5686 non-null   int64
#  8   k       5686 non-null   int64
#  9   e       5686 non-null   int64
#  10  e.1     5686 non-null   int64
#  11  s.1     5686 non-null   int64
#  12  s.2     5686 non-null   int64
#  13  w       5686 non-null   int64
#  14  w.1     5686 non-null   int64
#  15  p.2     5686 non-null   int64
#  16  w.2     5686 non-null   int64
#  17  o       5686 non-null   int64
#  18  p.3     5686 non-null   int64
#  19  k.1     5686 non-null   int64
#  20  s.3     5686 non-null   int64
#  21  u       5686 non-null   int64
# dtypes: int64(22)
# memory usage: 977.4 KB
# 2022-04-20 19:04:56,173 Spinning up shadow endpoint
# 2022-04-20 19:04:56,173 Creating endpoint-config with name sm-clarify-config-1650481496-67fd
# 2022-04-20 19:04:56,278 Creating endpoint: 'sm-clarify-DEMO-clarify-model-1650481496-9d04'
# 2022-04-20 19:04:56,682 Using endpoint name: sm-clarify-DEMO-clarify-model-1650481496-9d04
# 2022-04-20 19:04:56,682 Waiting for endpoint ...
# 2022-04-20 19:04:56,682 Checking endpoint status:
# Legend:
# (OutOfService: x, Creating: -, Updating: -, InService: !, RollingBack: <, Deleting: o, Failed: *)
# 2022-04-20 19:07:57,091 Endpoint is in service after 180 seconds
# 2022-04-20 19:07:57,092 Endpoint ready.
# 2022-04-20 19:07:57,094 The number of requested samples 15 is too small given the number of features 22
# 2022-04-20 19:07:57,094 SHAP n_samples 15
# 2022-04-20 19:07:57,223 =====================================================
# 2022-04-20 19:07:57,223 Shap analyzer: explaining 5686 rows, 22 columns...
# 2022-04-20 19:07:57,223 =====================================================
#   0% (0 of 5686) |                       | Elapsed Time: 0:00:00 ETA:  --:--:--
#  56% (3240 of 5686) |###########         | Elapsed Time: 0:00:30 ETA:   0:00:22
# 100% (5686 of 5686) |####################| Elapsed Time: 0:00:51 Time:  0:00:51
# 2022-04-20 19:08:48,535 getting explanations took 51.31 seconds.
# 2022-04-20 19:08:48,536 ===================================================
# 2022-04-20 19:08:48,978 converting explanations to tabular took 0.44 seconds.
# 2022-04-20 19:08:48,978 ===================================================
# 2022-04-20 19:08:48,981 Wrote baseline used to compute explanations to: /opt/ml/processing/output/explanations_shap/baseline.csv
# 2022-04-20 19:08:49,141 Wrote 5686 local explanations to: /opt/ml/processing/output/explanations_shap/out.csv
# 2022-04-20 19:08:49,142 writing local explanations took 0.16 seconds.
# 2022-04-20 19:08:49,142 ===================================================
# 2022-04-20 19:08:49,145 aggregating local explanations took 0.00 seconds.
# 2022-04-20 19:08:49,145 ===================================================
# 2022-04-20 19:08:49,145 Shap analysis finished.
# 2022-04-20 19:08:49,145 Stop using endpoint: sm-clarify-DEMO-clarify-model-1650481496-9d04
# 2022-04-20 19:08:49,145 Deleting endpoint configuration with name: sm-clarify-config-1650481496-67fd
# 2022-04-20 19:08:49,261 Deleting endpoint with name: sm-clarify-DEMO-clarify-model-1650481496-9d04
# 2022-04-20 19:08:49,409 Model endpoint delivered 109.27277 requests per second and a total of 5688 requests over 52 seconds
# 2022-04-20 19:09:06,172 Stop using endpoint: None
#
# 2022-04-20 19:09:13,287 jupyter nbconvert --to html --output /opt/ml/processing/output/report.html /opt/ml/processing/output/report.ipynb --template sagemaker-xai
# [NbConvertApp] Converting notebook /opt/ml/processing/output/report.ipynb to html
# [NbConvertApp] Writing 576037 bytes to /opt/ml/processing/output/report.html
# 2022-04-20 19:09:14,270 HTML report '/opt/ml/processing/output/report.html' generated successfully.
# 2022-04-20 19:09:14,270 wkhtmltopdf -q /opt/ml/processing/output/report.html /opt/ml/processing/output/report.pdf
# 2022-04-20 19:09:14,823 PDF report '/opt/ml/processing/output/report.pdf' generated successfully.
# 2022-04-20 19:09:14,824 Collected analyses:
# {
#     "version": "1.0",
#     "explanations": {
#         "kernel_shap": {
#             "label0": {
#                 "global_shap_values": {
#                     "x": 0.022696198359188728,
#                     "s": 0.023402617898120297,
#                     "n": 0.023373719102985673,
#                     "t": 0.023583169261620993,
#                     "p.1": 0.09722792741933205,
#                     "f": 0.022514324833932148,
#                     "c": 0.023688318459516695,
#                     "n.1": 0.027743358778958047,
#                     "k": 0.04725642634365155,
#                     "e": 0.02516788785574845,
#                     "e.1": 0.022841279089865697,
#                     "s.1": 0.027993927868020938,
#                     "s.2": 0.022946025291814335,
#                     "w": 0.022565696873246173,
#                     "w.1": 0.022758631577870003,
#                     "p.2": 0.023369935236144418,
#                     "w.2": 0.022294337356643372,
#                     "o": 0.022603265057606573,
#                     "p.3": 0.023909724598705783,
#                     "k.1": 0.03550709467372006,
#                     "s.3": 0.025111663473897396,
#                     "u": 0.10463172697455521
#                 },
#                 "expected_value": 0.002383912680670619
#             }
#         }
#     }
# }
# 2022-04-20 19:09:14,824 exit_message: Completed: SageMaker XAI Analyzer ran successfully
# ---!

# %%
explainability_output_path
# Out:
# 's3://sagemaker-us-east-1-714861692883/sagemaker/DEMO-sagemaker-clarify/clarify-explainability'

# %%
import awswrangler as wr

local_explanations_out = wr.s3.read_csv(explainability_output_path + '/explanations_shap/out.csv')
feature_names = [str.replace(c, "_label0", "") for c in local_explanations_out.columns.to_series()]
local_explanations_out.columns = feature_names

selected_example = 111
print(
    "Example number:",
    selected_example,
    "\nwith model prediction:",
    sum(local_explanations_out.iloc[selected_example]) > 0,
)
print("\nFeature values -- Label", train.iloc[selected_example])
local_explanations_out.iloc[selected_example].plot(
    kind="bar", title="Local explanation for the example number " + str(selected_example), rot=90
)
# Out:
# Example number: 111
# with model prediction: True
#
# Feature values -- Label p       1
# x       5
# s       2
# n       3
# t       1
# p.1     2
# f       1
# c       0
# n.1     0
# k      10
# e       1
# e.1     1
# s.1     0
# s.2     0
# w       7
# w.1     7
# p.2     0
# w.2     2
# o       1
# p.3     4
# k.1     1
# s.3     3
# u       5
# Name: 5455, dtype: int64
